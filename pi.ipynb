# %%
from pageindex import PageIndexClient
 
pi_client = PageIndexClient(api_key="2cd460c1ab594e63b97ee000c4a05b7f")

result = pi_client.submit_document("/Users/jinyiw/Documents/claude-projects/deep_research_agent/contracts/反馈0730-【已审查】（190号）互联网类系统CDN加速服务（三年）采购合同HT-ZRUB-2025-07-01-08-C002.docx.pdf")
doc_id = result["doc_id"]
status = pi_client.get_document(doc_id)["status"]
if status == "completed":
    print('File processing completed')

# %%
import pageindex.utils as utils
tree_result = pi_client.get_tree(doc_id,node_summary=True)["result"]
utils.print_tree(tree_result, exclude_fields=['text'])
# Out:
# [{'title': '第一条 通则',
#   'node_id': '0000',
#   'page_index': 3,
#   'summary': 'This document outlines the general terms...'},
#  {'title': '第二条 账号',
#   'node_id': '0001',
#   'page_index': 3,
#   'summary': '该文本详细阐述了腾讯云账号的注册要求、用途、安全保管责任、使用规范以及账号信息的...'},
#  {'title': '第三条 服务',
#   'node_id': '0002',
#   'page_index': 4,
#   'prefix_summary': '# 第三条 服务\n',
#   'nodes': [{'title': '3.1 服务开通',
#              'node_id': '0003',
#              'page_index': 4,
#              'summary': '本部分内容介绍了腾讯云的服务开通流程及相关规定。甲方可以通过官网或客户经理选购服...'},
#             {'title': '3.2 服务费用',
#              'node_id': '0004',
#              'page_index': 5,
#              'summary': 'This document outlines the service fees ...'}]},
#  {'title': '第四条 第三方产品或服务',
#   'node_id': '0005',
#   'page_index': 8,
#   'summary': '该文本规定了甲方通过腾讯云获取第三方产品或服务的责任划分，明确了第三方运营方与甲...'},
#  {'title': '第五条 网络安全和网络秩序',
#   'node_id': '0006',
#   'page_index': 8,
#   'summary': 'This document outlines the obligations o...'},
# ...

# %%
tree_result
# Out:
# [{'title': '第一条 通则',
#   'node_id': '0000',
#   'page_index': 3,
#   'summary': "This document outlines the general terms for Tencent Cloud services, defining them as internet resource collaboration and related software services. It clarifies Tencent Cloud's neutral role and the user's responsibility for their own operations. The agreement, along with published service rules, is legally binding. Users must also adhere to local laws for services used outside mainland China.",
# ...

# %%
tree_result
# Out:
# {'title': '第十一条 通知和送达',
#  'node_id': '0012',
#  'page_index': 15,
#  'text': '# 第十一条 通知和送达\n\n11.1 腾讯云可通过网页公告、系统通知、站内信、电子邮件、手机短信、专属服务沟通工具、函件等方式中的一种或多种向甲方发送与腾讯云服务有关的业务通知、服务提示、账单信息、缴费/续费通知、验证消息、营销信息以及服务规则更新、违规处置等各种通知和信息。前述通知和信息在以下情况下视为已送达：\n\n（1）交专人递送的，在收件人签收时视为已送达。\n（2）以网页公告等形式公布的，一经公布即生效（另有说明除外）。\n（3）以电子形式发送的，包括系统通知、站内信、电子邮件、手机短信、专属服务沟通工具等形式，在发送成功后视为已送达。\n（4）以邮资预付的快递公司递送或以挂号信递送的，以投邮后的第3天视为已送达。\n\n如果送达时间为法定节假日的，则以送达后首个工作日为送达日。\n\n11.2 为了使甲方能够及时收到腾讯云的通知和信息，腾讯云可能通过多个方式向甲方发送。同时，腾讯云也为甲方提供了通知和信息的订阅工具，甲方可以根据自身所需选择使用或关闭某些通知方式和某些类型的信息。甲方选择关闭接收某些通知和信息的，甲方不能因自己未订阅该类型的通知和信息而主张这些通知和信息对甲方不生效。\n\n11.3 甲方应当根据腾讯云官网公布的腾讯云的联系方式向腾讯云发送通知。如果甲方有专属客户经理、客服代表，甲方也可以通过他们向腾讯云提出请求。如果甲方未按照约定方式和途径通知腾讯云，甲方的通知可能未能送达腾讯云或迟延送达腾讯云。\n'}
